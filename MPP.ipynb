# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#new

# %%
df = pd.read_csv("mobile_phone_price.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                  Name  Rating  \
# 0             0           0                 Samsung Galaxy F14 5G    4.65
# 1             1           1                    Samsung Galaxy A11    4.20
# 2             2           2                    Samsung Galaxy A13    4.30
# 3             3           3                    Samsung Galaxy F23    4.10
# 4             4           4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10
#
#    Spec_score                      No_of_sim       Ram            Battery  \
# 0          68  Dual Sim, 3G, 4G, 5G, VoLTE,   4 GB RAM  6000 mAh Battery
# 1          63      Dual Sim, 3G, 4G, VoLTE,   2 GB RAM  4000 mAh Battery
# 2          75      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery
# 3          73      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM   6000 mAh Battery
# 4          69      Dual Sim, 3G, 4G, VoLTE,   4 GB RAM  5000 mAh Battery
#
#       Display                                             Camera  \
# ...

# %%
df.shape
# Out:
# (1370, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0.1       1370 non-null   int64
#  1   Unnamed: 0         1370 non-null   int64
#  2   Name               1370 non-null   object
#  3   Rating             1370 non-null   float64
#  4   Spec_score         1370 non-null   int64
#  5   No_of_sim          1370 non-null   object
#  6   Ram                1370 non-null   object
#  7   Battery            1370 non-null   object
#  8   Display            1370 non-null   object
#  9   Camera             1370 non-null   object
#  10  External_Memory    1370 non-null   object
#  11  Android_version    927 non-null    object
#  12  Price              1370 non-null   object
#  13  company            1370 non-null   object
#  14  Inbuilt_memory     1352 non-null   object
#  15  fast_charging      1281 non-null   object
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Name'].value_counts()
# Out:
# Name
# Realme Narzo N55 (6GB RAM + 128GB)    3
# Vivo S19 Pro                          2
# Samsung Galaxy S21 FE (Snapdragon)    2
# Vivo V25 Pro (12GB RAM + 256GB)       2
# Vivo V30 5G                           2
#                                      ..
# Poco C55                              1
# Poco C61 (6GB RAM + 128GB)            1
# iQOO 9 Pro 5G (12GB RAM + 256GB)      1
# iQOO 13 Pro                           1
# Poco C65 (8GB RAM + 256GB)            1
# Name: count, Length: 1334, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 1334

# %%
df.sample(3)
# Out:
#      Unnamed: 0.1                                     Name  Rating  \
# 988           988  Motorola Edge 40 Neo (12GB RAM + 256GB)     4.0
# 894           894                             Realme 12 5G     4.4
# 697           697                       Lenovo Legion Halo     4.7
#
#      Spec_score                      No_of_sim        Ram            Battery  \
# 988          85  Dual Sim, 3G, 4G, 5G, VoLTE,   12 GB RAM  5000 mAh Battery
# 894          78  Dual Sim, 3G, 4G, 5G, VoLTE,    6 GB RAM  5000 mAh Battery
# 697          87  Dual Sim, 3G, 4G, 5G, VoLTE,   16 GB RAM  5600 mAh Battery
#
#          Display                                             Camera  \
# 988  6.55 inches   50 MP + 13 MP Dual Rear &amp; 32 MP Front Camera
# 894  6.72 inches    108 MP + 2 MP Dual Rear &amp; 8 MP Front Camera
# 697  6.67 inches  50 MP + 13 MP + 2 MP Triple Rear &amp; 16 MP F...
#
#                      External_Memory Android_version   Price   company  \
# ...

# %%
df['Processor'].value_counts()
# Out:
# Processor
# Octa Core              1237
# Octa Core Processor      75
# Quad Core                11
# Deca Core                 3
# 1.6 GHz Processor         3
# 2 GHz Processor           2
# Nine Core                 2
# Nine-Cores                2
# Nine Cores                2
# 1.8 GHz Processor         1
# 1.3 GHz Processor         1
# Deca Core Processor       1
# 2.3 GHz Processor         1
# 128 GB inbuilt            1
# Name: count, dtype: int64

# %%
df['Processor_name'].value_counts()
# Out:
# Processor_name
# Snapdragon 8+ Gen1    58
# Snapdragon 8 Gen2     55
# Snapdragon 8 Gen3     44
# Snapdragon 695        36
# Snapdragon 680        34
#                       ..
# Snapdragon (6 nm)      1
# Tiger   T616           1
# Tiger  T616            1
# Helio  A22             1
# Helio A25              1
# Name: count, Length: 276, dtype: int64

# %%
df.drop(columns="Unnamed: 0.1", inplace=True)

# %%
df['No_of_sim'].value_counts()
# Out:
# No_of_sim
# Dual Sim, 3G, 4G, 5G, VoLTE,             818
# Dual Sim, 3G, 4G, VoLTE,                 419
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G,        91
# Single Sim, 3G, 4G, 5G, VoLTE,            20
# Dual Sim, 3G, 4G,                         13
# Single Sim, 3G, 4G, VoLTE,                 6
# No Sim Supported,                          1
# Single Sim, 3G, 4G, 5G, VoLTE, Vo5G,       1
# Dual Sim, 3G, VoLTE,                       1
# Name: count, dtype: int64

# %%
df.drop(columns = ['No_of_sim'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1370 non-null   object
#  1   Rating             1370 non-null   float64
#  2   Spec_score         1370 non-null   int64
#  3   Ram                1370 non-null   object
#  4   Battery            1370 non-null   object
#  5   Display            1370 non-null   object
#  6   Camera             1370 non-null   object
#  7   External_Memory    1370 non-null   object
#  8   Android_version    927 non-null    object
#  9   Price              1370 non-null   object
#  10  company            1370 non-null   object
#  11  Inbuilt_memory     1352 non-null   object
#  12  fast_charging      1281 non-null   object
#  13  Screen_resolution  1368 non-null   object
#  14  Processor          1342 non-null   object
#  15  Processor_name     1370 non-null   object
# ...

# %% [markdown]
# For price,

# %%
df['Price'].value_counts()
# Out:
# Price
# 29,990    37
# 19,990    28
# 14,999    26
# 14,990    26
# 9,990     24
#           ..
# 13,290     1
# 13,267     1
# 12,194     1
# 11,539     1
# 26,479     1
# Name: count, Length: 449, dtype: int64

# %%
df['Price'] = df['Price'].str.replace(",", "")

# %%
df['Price'].value_counts()
# Out:
# Price
# 29990    37
# 19990    28
# 14999    26
# 14990    26
# 9990     24
#          ..
# 13290     1
# 13267     1
# 12194     1
# 11539     1
# 26479     1
# Name: count, Length: 449, dtype: int64

# %%
df['Price'].astype('int32')
# Out:
# 0         9999
# 1         9990
# 2        11999
# 3        11999
# 4        11999
#          ...
# 1365     18999
# 1366     24990
# 1367     23990
# 1368     22499
# 1369    119990
# Name: Price, Length: 1370, dtype: int32

# %% [markdown]
# Now cleaning on Ram

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8 GB RAM          528
# 4 GB RAM          254
# 12 GB RAM         246
# 6 GB RAM          214
# 16 GB RAM          41
# 3 GB RAM           38
# 2 GB RAM           22
# 256 GB inbuilt      8
# 128 GB inbuilt      7
# 18 GB RAM           4
# 512 GB inbuilt      3
# 24 GB RAM           2
# 1 GB RAM            1
# Helio G90T          1
# 1.5 GB RAM          1
# Name: count, dtype: int64

# %% [markdown]
# As seen above there are some unnecessary values  like battery, helio and that inbuilt so removing that

# %%
#taking only those values which have the word RAM in it 

df["Ram"] = df["Ram"].apply(lambda x: x if "RAM" in x else None)

# %%
df["Ram"].value_counts()
# Out:
# Ram
# 8 GB RAM      528
# 4 GB RAM      254
# 12 GB RAM     246
# 6 GB RAM      214
# 16 GB RAM      41
# 3 GB RAM       38
# 2 GB RAM       22
# 18 GB RAM       4
# 24 GB RAM       2
# 1 GB RAM        1
# 1.5 GB RAM      1
# Name: count, dtype: int64

# %%
df["Ram"] = df["Ram"].str.replace("GB", "" ).str.strip()
df["Ram"] = df["Ram"].str.replace("RAM", "").str.strip()

# %%
df["Ram"].value_counts()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1370 non-null   object
#  1   Rating             1370 non-null   float64
#  2   Spec_score         1370 non-null   int64
#  3   Ram                1351 non-null   object
#  4   Battery            1370 non-null   object
#  5   Display            1370 non-null   object
#  6   Camera             1370 non-null   object
#  7   External_Memory    1370 non-null   object
#  8   Android_version    927 non-null    object
#  9   Price              1370 non-null   object
#  10  company            1370 non-null   object
#  11  Inbuilt_memory     1352 non-null   object
#  12  fast_charging      1281 non-null   object
#  13  Screen_resolution  1368 non-null   object
#  14  Processor          1342 non-null   object
#  15  Processor_name     1370 non-null   object
# ...

# %%
df["Ram"] = df['Ram'].astype('float32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1370 non-null   object
#  1   Rating             1370 non-null   float64
#  2   Spec_score         1370 non-null   int64
#  3   Ram                1351 non-null   float32
#  4   Battery            1370 non-null   object
#  5   Display            1370 non-null   object
#  6   Camera             1370 non-null   object
#  7   External_Memory    1370 non-null   object
#  8   Android_version    927 non-null    object
#  9   Price              1370 non-null   object
#  10  company            1370 non-null   object
#  11  Inbuilt_memory     1352 non-null   object
#  12  fast_charging      1281 non-null   object
#  13  Screen_resolution  1368 non-null   object
#  14  Processor          1342 non-null   object
#  15  Processor_name     1370 non-null   object
# ...

# %%
df['Ram'].corr(df['Price'])
# Out:
# np.float64(0.652325785240589)

# %%
df['Battery'].value_counts()
# Out:
# Battery
# 5000 mAh Battery                       693
# 4500 mAh Battery                       116
# 6000 mAh Battery                       102
# 5000 mAh Battery                        59
# 4000 mAh Battery                        36
#                                       ...
# 6.75 inches, 720 x 1600 px Display       1
# 4250 mAh Battery                         1
# 4750 mAh Battery                         1
# 5330 mAh Battery                         1
# 4500 mAh Battery                         1
# Name: count, Length: 89, dtype: int64

# %%
df['Battery'] = df['Battery'].apply(lambda a: a if "Battery" in a else None)

# %%
df['Battery'].value_counts()
# Out:
# Battery
# 5000 mAh Battery     693
# 4500 mAh Battery     116
# 6000 mAh Battery     102
# 5000 mAh Battery      59
# 4000 mAh Battery      36
#                     ...
# 4250 mAh Battery       1
# 4980 mAh Battery       1
# 4750 mAh Battery       1
# 5330 mAh Battery       1
# 4500 mAh Battery       1
# Name: count, Length: 87, dtype: int64

# %%
df['Battery'] = df['Battery'].str.replace("mAh Battery", "").str.strip()

# %%
df['Battery'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1370 entries, 0 to 1369
# Series name: Battery
# Non-Null Count  Dtype
# --------------  -----
# 1368 non-null   object
# dtypes: object(1)
# memory usage: 10.8+ KB

# %%
df['Battery'] = df['Battery'].fillna(0) 
df['Battery'].astype('int32')
# Out:
# 0       6000
# 1       4000
# 2       5000
# 3       6000
# 4       5000
#         ...
# 1365    5000
# 1366    5000
# 1367    5000
# 1368    5000
# 1369    4600
# Name: Battery, Length: 1370, dtype: int32

# %% [markdown]
# cleaning inbuilt memory

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1370 entries, 0 to 1369
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1370 non-null   object
#  1   Rating             1370 non-null   float64
#  2   Spec_score         1370 non-null   int64
#  3   Ram                1351 non-null   float32
#  4   Battery            1370 non-null   object
#  5   Display            1370 non-null   object
#  6   Camera             1370 non-null   object
#  7   External_Memory    1370 non-null   object
#  8   Android_version    927 non-null    object
#  9   Price              1370 non-null   object
#  10  company            1370 non-null   object
#  11  Inbuilt_memory     1352 non-null   object
#  12  fast_charging      1281 non-null   object
#  13  Screen_resolution  1368 non-null   object
#  14  Processor          1342 non-null   object
#  15  Processor_name     1370 non-null   object
# ...

# %%
df['Inbuilt_memory'].value_counts()
# Out:
# Inbuilt_memory
# 128 GB inbuilt    645
# 256 GB inbuilt    405
# 64 GB inbuilt     184
# 512 GB inbuilt     59
# 32 GB inbuilt      48
# 1 TB inbuilt        5
# 16 GB inbuilt       3
# Octa Core           1
# 258 GB inbuilt      1
# 8 GB inbuilt        1
# Name: count, dtype: int64

# %%
df['Inbuilt_memory'] = df['Inbuilt_memory'].apply(lambda x: x if isinstance(x, str) and ("GB" in x or "TB" in x) else None)

# %%
df['Inbuilt_memory'] = df['Inbuilt_memory'].str.replace("GB inbuilt","").str.strip()

# %%
df['Inbuilt_memory']
# Out:
# 0       128
# 1        32
# 2        64
# 3        64
# 4        64
#        ...
# 1365     64
# 1366    128
# 1367    256
# 1368    256
# 1369    256
# Name: Inbuilt_memory, Length: 1370, dtype: object

# %%
df.sample(3)
# Out:
#                     Name  Rating  Spec_score   Ram Battery     Display  \
# 1052  Motorola Razr 2019    4.25          73   6.0    2510  6.2 inches
# 682        LG Stylo 7 5G    4.20          76   4.0    4000  6.8 inches
# 649    Google Pixel Fold    4.55          90  12.0    4821  7.6 inches
#
#                                                  Camera  \
# 1052                 16 MP Rear &amp; 5 MP Front Camera
# 682   48 MP + 8 MP + 2 MP Triple Rear &amp; 13 MP Fr...
# 649   48 MP + 10.8 MP + 10.8 MP Triple Rear &amp; 9....
#
#                                         External_Memory Android_version  \
# 1052                 16 MP Rear &amp; 5 MP Front Camera             NaN
# 682                    Memory Card Supported, upto 2 TB              10
# 649   48 MP + 10.8 MP + 10.8 MP Triple Rear &amp; 9....              13
#
#        Price   company Inbuilt_memory       fast_charging  \
# 1052  149999  Motorola            128   18W Fast Charging
# ...

# %%
df.drop(columns=['Android_version', 'Processor', 'External_Memory'], inplace=True)

# %%
df['Camera']
df['Display'] = df['Display'].apply(lambda x:  x if 'inches' in x else None)
df['Display']
# Out:
# 0       6.6 inches
# 1       6.4 inches
# 2       6.6 inches
# 3       6.4 inches
# 4       6.5 inches
#            ...
# 1365    6.6 inches
# 1366    6.8 inches
# 1367    6.6 inches
# 1368    6.6 inches
# 1369     10 inches
# Name: Display, Length: 1370, dtype: object

# %%
df['Display']= df['Display'].str.replace('inches', "").str.strip()
df['Display'] = df['Display'].astype('float32')
df = df.dropna(subset = ['Display'])

# %%
df = df.copy()

# %%
df[['Width', 'Height']] = df['Screen_resolution'].str.extract(r'(\d+)\s*x\s*(\d+)')

# %%
df[['Width', 'Height']] = df['Screen_resolution'].str.extract(r'(\d+)\s*x\s*(\d+)')

# %%
df.dropna(subset=['Width', 'Height'], inplace=True)

# %%
df['Width'] = df['Width'].astype('int32')
df['Height'] = df['Height'].astype('int32')
df.drop(columns=['Screen_resolution'], inplace=True)

# %%
import re 
def backCamera_MP(x):
    matching_pattern = re.search(r'(\d+) MP' ,x)
    return matching_pattern.group(1) if matching_pattern else None
def frontCamera_MP(x):
    matching_pattern = re.search(r'&amp;\s*(\d+)\s*MP', x)
    return matching_pattern.group(1) if matching_pattern else None


def Numberof_RearCamera(x):
    matching_pattern = re.search(r'(Dual|Triple|Quad) Rear',x)
    return matching_pattern.group(1) if matching_pattern else None

df['Back Camera MP'] = df['Camera'].apply(backCamera_MP)
df['Front Camera MP'] = df['Camera'].apply(frontCamera_MP)
df['Number of Rear Camera'] = df['Camera'].apply(Numberof_RearCamera)

# %%
df['Processor'] = df['Processor_name'].apply(
    lambda x: 'snapdragon' if 'Snapdragon' in x else
                 'dimensity' if 'Dimensity' in x else
                 'helio' if 'Helio' in x else
                 'unisoc' if 'Unisoc' in x else
                 'exynos' if 'Exynos' in x else
                 'tiger' if 'Tiger' in x else
                 'tensor' if 'Tensor' in x else
                 'other'
)

# %%
df['PPI'] = (df['Width']**2 + df['Height']**2)**0.5 / df['Display'].astype('float32')
df.drop(['Height', 'Width','Camera', 'Processor_name','Spec_score'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                    Name  Rating  Ram Battery  Display  Price  \
# 0                 Samsung Galaxy F14 5G    4.65  4.0    6000      6.6   9999
# 1                    Samsung Galaxy A11    4.20  2.0    4000      6.4   9990
# 2                    Samsung Galaxy A13    4.30  4.0    5000      6.6  11999
# 3                    Samsung Galaxy F23    4.10  4.0    6000      6.4  11999
# 4  Samsung Galaxy A03s (4GB RAM + 64GB)    4.10  4.0    5000      6.5  11999
#
#    company Inbuilt_memory       fast_charging Back Camera MP Front Camera MP  \
# 0  Samsung            128   25W Fast Charging             50              13
# 1  Samsung             32   15W Fast Charging             13               8
# 2  Samsung             64   25W Fast Charging             50               8
# 3  Samsung             64                 NaN             48              13
# 4  Samsung             64   15W Fast Charging             13               5
#
# ...

# %%
df['Name'] = df['company'].apply(lambda x: x.split()[0])
df.rename(columns={'Name':'Brand'}, inplace=True)
df["Brand"] = df["Brand"].str.upper()
df.head()
# Out:
#      Brand  Rating  Ram Battery  Display  Price  company Inbuilt_memory  \
# 0  SAMSUNG    4.65  4.0    6000      6.6   9999  Samsung            128
# 1  SAMSUNG    4.20  2.0    4000      6.4   9990  Samsung             32
# 2  SAMSUNG    4.30  4.0    5000      6.6  11999  Samsung             64
# 3  SAMSUNG    4.10  4.0    6000      6.4  11999  Samsung             64
# 4  SAMSUNG    4.10  4.0    5000      6.5  11999  Samsung             64
#
#         fast_charging Back Camera MP Front Camera MP Number of Rear Camera  \
# 0   25W Fast Charging             50              13                  Dual
# 1   15W Fast Charging             13               8                Triple
# 2   25W Fast Charging             50               8                  Quad
# 3                 NaN             48              13                  Quad
# 4   15W Fast Charging             13               5                Triple
#
#   Processor         PPI
# 0    exynos  399.864078
# 1     other  268.459141
# ...

# %%
df.drop(columns=['fast_charging', 'company','Rating'],axis = 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1367 entries, 0 to 1369
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  1367 non-null   object
#  1   Ram                    1349 non-null   float32
#  2   Battery                1367 non-null   object
#  3   Display                1367 non-null   float32
#  4   Price                  1367 non-null   object
#  5   Inbuilt_memory         1349 non-null   object
#  6   Back Camera MP         1367 non-null   object
#  7   Front Camera MP        1354 non-null   object
#  8   Number of Rear Camera  1314 non-null   object
#  9   Processor              1367 non-null   object
#  10  PPI                    1367 non-null   float64
# dtypes: float32(2), float64(1), object(8)
# memory usage: 117.5+ KB

# %%
df['Number of Rear Camera'] = df['Number of Rear Camera'].replace({
    'Dual': '2', 
    'Triple': '3', 
    'Quad': '4'
}).fillna('1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1367 entries, 0 to 1369
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  1367 non-null   object
#  1   Ram                    1349 non-null   float32
#  2   Battery                1367 non-null   object
#  3   Display                1367 non-null   float32
#  4   Price                  1367 non-null   object
#  5   Inbuilt_memory         1349 non-null   object
#  6   Back Camera MP         1367 non-null   object
#  7   Front Camera MP        1354 non-null   object
#  8   Number of Rear Camera  1367 non-null   object
#  9   Processor              1367 non-null   object
#  10  PPI                    1367 non-null   float64
# dtypes: float32(2), float64(1), object(8)
# memory usage: 117.5+ KB

# %%
df.dropna(subset= ['Ram', 'Inbuilt_memory','Front Camera MP'], inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1336 entries, 0 to 1369
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  1336 non-null   object
#  1   Ram                    1336 non-null   float32
#  2   Battery                1336 non-null   object
#  3   Display                1336 non-null   float32
#  4   Price                  1336 non-null   object
#  5   Inbuilt_memory         1336 non-null   object
#  6   Back Camera MP         1336 non-null   object
#  7   Front Camera MP        1336 non-null   object
#  8   Number of Rear Camera  1336 non-null   object
#  9   Processor              1336 non-null   object
#  10  PPI                    1336 non-null   float64
# dtypes: float32(2), float64(1), object(8)
# memory usage: 114.8+ KB

# %%
df['Inbuilt_memory'] = df['Inbuilt_memory'].apply(lambda x: 1024 if 'TB' in str(x) else x)
df['Inbuilt_memory'] = df['Inbuilt_memory'].astype('int32')

# %%
df['Price'] = df['Price'].astype('float32')
df['Number of Rear Camera'] = df['Number of Rear Camera'].astype('float32')
df['Front Camera MP'] = df['Front Camera MP'].astype('float32')
df['Back Camera MP'] = df['Back Camera MP'].astype('float32')

# %%
sns.pairplot(df[["Price", "Ram","Display", "PPI"]])
plt.show()

# %%
#median price vs different features
sns.set_style("whitegrid")

fig, axes = plt.subplots(3, 1, figsize=(12, 12))


sns.barplot(x="Ram", y="Price", data=df, hue='Ram',legend=None, estimator=np.median, ax=axes[0], palette="Blues_d")
axes[0].set_title("Median Price for Each RAM size")
axes[0].set_xlabel("RAM (GB)")
axes[0].set_ylabel("Median Price")


sns.barplot(x="Processor", y="Price", data=df,hue='Processor',legend=None, estimator=np.median, ax=axes[1], palette="Greens_d")
axes[1].set_title("Median Price for Each Processor")
axes[1].set_xlabel("Processor")
axes[1].set_ylabel("Median Price")
axes[1].tick_params(axis='x', rotation=45)


sns.barplot(x="Brand", y="Price", data=df,hue='Brand',legend=None, estimator=np.median, ax=axes[2], palette="Reds_d")
axes[2].set_title("Median Price for Each Brand")
axes[2].set_xlabel("Brand Name")
axes[2].set_ylabel("Median Price")
axes[2].tick_params(axis='x', rotation=90)


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Brand', y='Price', hue='Brand',data=df, palette='Set3')
plt.xticks(rotation=45)
plt.title('Price Distribution by Brand')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Price'], color='skyblue')
plt.xlabel('Price')
plt.title('Box Plot of Price Distribution')
# Out:
# Text(0.5, 1.0, 'Box Plot of Price Distribution')

# %%
price_bins = [0, 20000, 40000, 60000, 80000, 100000, float('inf')]
price_labels = ['0–20K', '20K–40K', '40K–60K', '60K–80K', '80K–100K', '100K+']


df['Price_Range'] = pd.cut(df['Price'], bins=price_bins, labels=price_labels)

df['Price_Range'].value_counts()
# Out:
# Price_Range
# 0–20K       637
# 20K–40K     363
# 40K–60K     155
# 60K–80K      79
# 100K+        53
# 80K–100K     49
# Name: count, dtype: int64

# %%
df = df[df['Price'] <= 100000]
df= df.drop(columns=['Price_Range'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1283 entries, 0 to 1368
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Brand                  1283 non-null   object
#  1   Ram                    1283 non-null   float32
#  2   Battery                1283 non-null   object
#  3   Display                1283 non-null   float32
#  4   Price                  1283 non-null   float32
#  5   Inbuilt_memory         1283 non-null   int32
#  6   Back Camera MP         1283 non-null   float32
#  7   Front Camera MP        1283 non-null   float32
#  8   Number of Rear Camera  1283 non-null   float32
#  9   Processor              1283 non-null   object
#  10  PPI                    1283 non-null   float64
# dtypes: float32(6), float64(1), int32(1), object(3)
# memory usage: 85.2+ KB

# %%
correlation_mat = df.drop(['Brand', 'Processor'], axis=1).corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_mat,annot=True, cmap= 'coolwarm', fmt='.2f',linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
sns
# Out:
# <module 'seaborn' from '/home/nischal/project_fds/lib/python3.12/site-packages/seaborn/__init__.py'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt


correlations = correlation_mat["Price"].sort_values(ascending=True)


colors = ['#6a0dad' if val >= 0 else 'lightgray' for val in correlations.values]

plt.figure(figsize=(10,6))
sns.barplot(x=correlations.index, y=correlations.values, hue = correlations.index, palette=colors)
plt.xticks(rotation=90)
plt.ylim(-0.4, 1)
plt.axhline(0, color='black', linestyle='--', linewidth=1)  
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import pandas as pd

categorical_columns = ['Brand', 'Processor']
encoding = OneHotEncoder(sparse_output=False).set_output(transform='pandas')
transformed = encoding.fit_transform(df[categorical_columns])

# one hot encoding only to categorical columns and concating with the original dataframe
concated_newdf = pd.concat([df, transformed], axis=1).drop(columns=categorical_columns)

# target variable in Y
Y = concated_newdf['Price']
X_transformed = concated_newdf.drop(columns='Price')

# scaled numerical columns
scaler1 = StandardScaler()
X_transformed[[
   'Ram', 'Battery', 'Display', 'Inbuilt_memory', 
   'Back Camera MP', 'Front Camera MP', 'Number of Rear Camera', 'PPI']] = \
    scaler1.fit_transform(X_transformed[[    
        'Ram', 'Battery', 'Display', 'Inbuilt_memory',
                            'Back Camera MP', 'Front Camera MP', 
                            'Number of Rear Camera', 'PPI']])


print(X_transformed.shape, Y.shape)
# Out:
# (1283, 38) (1283,)

# %%
X_transformed.info() 
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1283 entries, 0 to 1368
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ram                    1283 non-null   float64
#  1   Battery                1283 non-null   float64
#  2   Display                1283 non-null   float64
#  3   Inbuilt_memory         1283 non-null   float64
#  4   Back Camera MP         1283 non-null   float64
#  5   Front Camera MP        1283 non-null   float64
#  6   Number of Rear Camera  1283 non-null   float64
#  7   PPI                    1283 non-null   float64
#  8   Brand_ASUS             1283 non-null   float64
#  9   Brand_COOLPAD          1283 non-null   float64
#  10  Brand_GIONEE           1283 non-null   float64
#  11  Brand_GOOGLE           1283 non-null   float64
#  12  Brand_HONOR            1283 non-null   float64
#  13  Brand_HUAWEI           1283 non-null   float64
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import learning_curve


def plot_learning_curve(model, X, Y, title):
    
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    train_sizes, train_scores, test_scores = learning_curve(
        model, X, Y, cv=kf, scoring="r2", train_sizes=np.linspace(0.1, 1.0, 10))
    
  
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    plt.figure(figsize=(8, 5))
    plt.plot(train_sizes, train_mean, "o-", color="blue", label="Training Score")
    plt.plot(train_sizes, test_mean, "o-", color="red", label="Validation Score")
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1, color="blue")
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.1, color="red")
    plt.ylim(0.4 , 1)
    plt.title(f"Learning Curve: {title}")
    plt.xlabel("Training Set Size")
    plt.ylabel("R² Score")
    plt.legend(loc="best")
    plt.show()

# %%
def train_model(model, X, Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2,  shuffle= True, random_state=42)
       
    model.fit(X_train, Y_train)
    
    Y_pred = model.predict(X_test)
    
    mse = mean_squared_error(Y_test, Y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(Y_test, Y_pred)
    
    print(f"Root Mean Squared Error (RMSE): {rmse}")
    print(f"R² Score: {r2}")
    
    residuals = Y_test - Y_pred
    plt.scatter(Y_test, residuals)
    plt.axhline(y=0, color='r', linestyle='--')
    plt.xlabel("True Values")
    plt.ylabel("Residuals")
    plt.title("Residual Plot")
    plt.show()
    
    cv_scores = cross_val_score(model, X, Y, cv=5, scoring='neg_mean_squared_error')
    cv_rmse = np.sqrt(-cv_scores)
    
    
    cv_r2_scores = cross_val_score(model, X, Y, cv=5, scoring='r2')
    
    print(f"Cross-validated RMSE: {cv_rmse.mean()}")
    print(f"Cross-validated R² Score: {cv_r2_scores.mean()}")
    
    plot_learning_curve(model,X_train,Y_train,(model))
    return r2,rmse, cv_r2_scores.mean(), cv_rmse.mean()

# %%
linear_r2, linear_rmse, linear_cv_r2, linear_cv_rmse = train_model(LinearRegression(), X_transformed, Y)
# Out:
# Root Mean Squared Error (RMSE): 12116.149582841783
# R² Score: 0.6916088205240212
# Cross-validated RMSE: 15107.539433761947
# Cross-validated R² Score: 0.49753187695088

# %% [markdown]
# cross validation MSE and training MSE have been almost same after 500 600 data so, model heavily underfits the data. As adding more data does not improve the generalization.

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR 
tree_reg = DecisionTreeRegressor(max_depth=8,random_state=42)
tree_r2, tree_rmse, tree_cv_r2, tree_cv_rmse  = train_model(tree_reg, X_transformed, Y)
# Out:
# Root Mean Squared Error (RMSE): 12111.573823529343
# R² Score: 0.6918417092550002
# Cross-validated RMSE: 15887.12401909843
# Cross-validated R² Score: 0.4383816300414298

# %%
forest_reg = RandomForestRegressor(random_state=101)
forest_r2, forest_rmse, forest_cv_r2, forest_cv_rmse= train_model(forest_reg, X_transformed,Y)
print(forest_reg.oob_score)
# Out:
# Root Mean Squared Error (RMSE): 8676.543275936543
# R² Score: 0.8418511021194873
# Cross-validated RMSE: 12342.26753329619
# Cross-validated R² Score: 0.6619145081103233
# False

# %%
import matplotlib.pyplot as plt

def plot_results(results):
   
    plt.figure(figsize=(12, 6))
    
    # Plot R^2 vs alpha
    plt.subplot(1, 3, 1)
    plt.plot(results['alpha'], results['r2'], 'o-', color = 'blue',label='R² Score')
   
    plt.xlabel('Alpha')
    plt.ylabel('R² Score')
    plt.title('R² vs Alpha')
    
    
    # Plot mse vs alpha
    plt.subplot(1, 3, 2)
    plt.plot(results['alpha'], results['mse'],'o-', color = 'red', label='MSE')
    
    plt.xlabel('Alpha')
    plt.ylabel('Mean Squared Error')
    plt.title('MSE vs Alpha')
    
    # Plot mae vs alpha
    plt.subplot(1, 3, 3)
    plt.plot(results['alpha'], results['mae'], 'o-', color = 'green',label='MAE')
    
    plt.xlabel('Alpha')
    plt.ylabel('Mean Absolute Error')
    plt.title('MAE vs Alpha')
    
    plt.tight_layout()
    plt.show()

# %%
from sklearn.linear_model import Ridge, Lasso

def train_model_with_alpha_cv(model_class, X, Y, alphas=np.linspace(1, 100, 10)):
    best_alpha = None
    best_r2 = -np.inf
    best_mse = np.inf
    best_mae = np.inf
    results = {'alpha': [], 'r2': [], 'mse': [], 'mae': []}
  
    for value in alphas:
        if model_class == 'ridge':
         model = Ridge(value)
        elif model_class == 'lasso':
         model = Lasso(alpha=value*50, max_iter=10000)
        else: 
            print("Value Error")
      
        r2_scores = cross_val_score(model, X, Y, cv=5, scoring='r2')
        mse_scores = cross_val_score(model, X, Y, cv=5, scoring='neg_mean_squared_error')
        mae_scores = cross_val_score(model, X, Y, cv=5, scoring='neg_mean_absolute_error')
        
        mean_r2 = r2_scores.mean()
        mean_mse = -mse_scores.mean() 
        mean_mae = -mae_scores.mean()  
       
        if(model_class == 'lasso'):
          results['alpha'].append(value*50)
          
        else: 
          results['alpha'].append(value)
          
        results['r2'].append(mean_r2)
        results['mse'].append(mean_mse)
        results['mae'].append(mean_mae)
        
        # best model
        if mean_r2 > best_r2:
            best_r2 = mean_r2
            if(model_class=='lasso'):
              best_alpha = value*50
            else: 
              best_alpha = value
        if mean_mse < best_mse:
            best_mse = mean_mse
        if mean_mae < best_mae:
            best_mae = mean_mae

   
    plot_results(results)
   
   
    print(f"Best Alpha: {best_alpha}")
    print(f"Best R² Score: {best_r2}")
    print(f"Best MSE: {best_mse}")
    print(f"Best MAE: {best_mae}")
    
    return best_r2, best_mse ** 0.5

# %%
from sklearn.preprocessing import PolynomialFeatures

numerical_columns = ['Ram', 'Battery', 'Display', 'Inbuilt_memory', 
					 'Back Camera MP', 'Front Camera MP', 'Number of Rear Camera', 'PPI']

print(numerical_columns)
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(concated_newdf[numerical_columns])

scaler = StandardScaler()
X_poly_scaled = scaler.fit_transform(X_poly)

X_remaining = X_transformed.iloc[:, 8:].values  # Remaining columns after polynomial features
X_poly_final = np.concatenate((X_poly_scaled, X_remaining), axis=1)
# Out:
# ['Ram', 'Battery', 'Display', 'Inbuilt_memory', 'Back Camera MP', 'Front Camera MP', 'Number of Rear Camera', 'PPI']

# %%
ridge_r2, ridge_rmse = train_model_with_alpha_cv('ridge', X_poly_final, Y)
# Out:
# Best Alpha: 100.0
# Best R² Score: 0.5302151881467136
# Best MSE: 214132243.08795202
# Best MAE: 10174.79945005509

# %%
lasso_r2, lasso_rmse = train_model_with_alpha_cv('lasso', X_poly_final  , Y)
# Out:
# Best Alpha: 1150.0
# Best R² Score: 0.5244176111327368
# Best MSE: 217468845.11181504
# Best MAE: 10008.549662951007

# %%
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np


X_train, X_test, y_train, y_test = train_test_split(X_transformed, Y, test_size=0.2, random_state=42)


rf = RandomForestRegressor(random_state=42, oob_score=True, bootstrap=True)

param_dist = {
    'n_estimators': [100, 200, 300, 400],
    'max_depth': [5, 10, 15, 20],  
    'min_samples_split': [5, 10, 15],  
    'min_samples_leaf': [2, 4, 6],     
    'max_features': ['sqrt', 'log2']   
}


random_search = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=50,
    cv=5,
    scoring='r2',
    n_jobs=-1,
    verbose=2,
    random_state=42
)


random_search.fit(X_train, y_train)

# Best model
best_rf = random_search.best_estimator_
print(f"Best Parameters: {random_search.best_params_}")


y_pred_best = best_rf.predict(X_test)


best_mae = mean_absolute_error(y_test, y_pred_best)
best_mse = mean_squared_error(y_test, y_pred_best)
best_rmse = np.sqrt(best_mse)
best_r2 = r2_score(y_test, y_pred_best)
best_r2_oob = best_rf.oob_score_

print(f"\nModel Performance:")
print(f"MAE: {best_mae:.4f}")
print(f"MSE: {best_mse:.4f}")
print(f"RMSE: {best_rmse:.4f}")
print(f"R² Score: {best_r2:.4f}")
print(f"OOB Score (approx CV): {best_rf.oob_score_:.4f}")
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   1.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=log2, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   1.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=2, min_samples_split=15, n_estimators=200; total time=   1.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.5s
# ...

# %%
residuals = y_test - y_pred_best
plt.scatter(y_test, residuals)
plt.axhline(y =0 , color = 'r', linestyle= '--')
plt.title("Residuals Plot for the best model")
plt.xlabel("True Values")
plt.ylabel("Residuals")
plt.show()

# %%
r2_scores = {"Linear Reg": linear_cv_r2, "Polynomial Lasso": lasso_r2, "Polynomial Ridge":ridge_r2, 'Decision Tree':tree_cv_r2, "Random Forest": forest_cv_r2, "Best Random Forest":best_r2_oob}
rmse_scores= {"Linear Reg": linear_cv_rmse, "Polynomial Lasso": lasso_rmse, "Polynomial Ridge":ridge_rmse, 'Decision Tree':tree_rmse, "Random Forest": forest_rmse, "Best Random Forest":best_rmse}


plt.figure(figsize=(10, 5))
bars = plt.bar(r2_scores.keys(), r2_scores.values(), color='skyblue')
plt.title("R² Scores of Different Models")
plt.ylabel("R² Score")
plt.xticks(rotation=45)
plt.ylim(0, 1)


for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

plt.show()

plt.figure(figsize=(10, 5))
bars = plt.bar(rmse_scores.keys(), rmse_scores.values(), color='lightcoral')
plt.title("RMSE Scores of Different Models")
plt.ylabel("RMSE")
plt.xticks(rotation=45)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
import pickle



with open("best_random_forest.pkl", "wb") as f:
    pickle.dump(best_rf, f)

with open("scaler1.pkl", "wb") as f:
    pickle.dump(scaler1, f)
